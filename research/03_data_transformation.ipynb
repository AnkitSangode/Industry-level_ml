# %%
# %pwd
import os
os.chdir("D:/Python/Industry level/Machine learning/Industry-level_ml")

# %%
from dataclasses import dataclass
from pathlib import Path

@dataclass(frozen=True)
class DataTransformationConfig:
    root_dir : Path
    data_path: Path

# %%
from mlProject.constants import *
from mlProject.utils.common import read_yaml,create_directories

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH,
        schema_filepath = SCHEMA_FILE_PATH
    ):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        self.schema = read_yaml(schema_filepath)

        create_directories([self.config.artifacts_root])

    def get_data_transformation_config(self) -> DataTransformationConfig:
        config = self.config.data_transformation

        create_directories([config.root_dir])

        data_transformation_config = DataTransformationConfig(
            root_dir = config.root_dir,
            data_path = config.data_path,
        )

        return data_transformation_config

# %%
import os
from mlProject import logger
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
class DataTransformation:
    def __init__(self,config = DataTransformationConfig):
        self.config = config

        #Note: We can add different data transformation techniques
        #such as scaler, PCA and all

        #In this dataset we have a ready dataset so we don't have to do anything 
        #We will just perform train test split


    def train_test_splitting(self):

        data = pd.read_csv(self.config.data_path)
        train,test = train_test_split(data)

        train.to_csv(os.path.join(self.config.root_dir,'train.csv'),index = False)
        test.to_csv(os.path.join(self.config.root_dir,'test.csv'),index = False)

        logger.info("Splitted data into training and testing")
        logger.info(train.shape)
        logger.info(test.shape)

        print(train.shape)
        print(test.shape)

# %%
try:
    config = ConfigurationManager()
    data_transformation_config = config.get_data_transformation_config()
    data_transformation = DataTransformation(config = data_transformation_config)
    data_transformation.train_test_splitting()
except Exception as e:
    raise e
# Out:
# [2025-07-20 18:55:47,760: INFO: common: YAML file config\config.yaml loaded successfully:]
# [2025-07-20 18:55:47,768: INFO: common: YAML file params.yaml loaded successfully:]
# [2025-07-20 18:55:47,771: INFO: common: YAML file schema.yaml loaded successfully:]
# [2025-07-20 18:55:47,776: INFO: common: created directory at: artifacts:]
# [2025-07-20 18:55:47,778: INFO: common: created directory at: artifacts/data_transformation:]
# [2025-07-20 18:55:47,949: INFO: 1530307773: Splitted data into training and testing:]
# [2025-07-20 18:55:47,950: INFO: 1530307773: (1199, 12):]
# [2025-07-20 18:55:47,951: INFO: 1530307773: (400, 12):]
# (1199, 12)
# (400, 12)
